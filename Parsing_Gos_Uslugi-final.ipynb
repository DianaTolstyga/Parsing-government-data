# %% [markdown]
# # Parsing House Management Data from GosUslugi portal

# %% [markdown]
# ## The code helps to parse house-level data from government portal. It uses API as well as other manually developed instruments to get the data. The received data is used to run regression analysis to see the effectiveness of SOE vs non SOE (State Owned Enterprices) house management companies.

# %%
pip install gosuslugi-api

# %%
#sw0 = HTTPClient()
#sw1 = GosUslugiAPIClient(keep_alive=True)
#sw1.get_organizations('3507007915')

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<2.9,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import time
import logging
from io import BytesIO
from typing import Union
from urllib.parse import urlencode
#from zipfile import Zipfile

# %%
import requests
from openpyxl import load_workbook

# %%
from gosuslugi_api.consts import REGION_CODES_AND_NAMES
from gosuslugi_api.exceptions import RegionCodeIsAbsentError

# %%
logger = logging.getLogger(__name__)

# %%
def _get_body_for_logging(body: Union[bytes, str]) -> str:
    try:
        if isinstance(body,bytes):
            return(b' BODY:' + body).decode('utf-8')
        elif isinstance(body, str):
            return 'BODY: ' + body
        else:
            return ''
    except UnicodeDecodeError:
        return ''

# %%
def _get_duration_for_logging(duration: str) -> str:
    if duration is not None:
        return '{0:.6f}s'.format(duration)
    else:
        return ''

# %%
class HTTPClient:
    GET_HTTP_METHOD = 'GET'
    POST_HTTP_METHOD = 'POST'
    PATCH_HTTP_METHOD = 'PATCH'
    PUT_HTTP_METHOD = 'PUT'
    
    BODY_LESS_METHODS = [GET_HTTP_METHOD]
    LOG_REQUEST_TEMPLATE = '%(method)s%(url)s%(request_body)s%(duration)s'
    LOG_RESPONSE_TEMPLATE = (
        LOG_REQUEST_TEMPLATE
        + ' - HTTP %(status_code)s%(response_body)s%(duration)s')
    
    def __init__(self, timeout=3, keep_alive=False, default_headers=None):
        self.timeout = timeout
        self.keep_alive = keep_alive
        self.default_headers = default_headers or {}
        self._session = None
        
    def _log_request(
           self, method, url, body, duration=None, log_method=logger.info):
        message_params = {
            'method':method, 'url':url,
            'request_body': _get_body_for_logging(body),
            'duration': _get_duration_for_logging(duration)}
        log_method(self.LOG_REQUEST_TEMPLATE, message_params)
        
        
    def _log_response(self, response, duration, log_method=logger.info):
        message_params = {
            'method': response.request.method,
            'url': response.request.url,
            'request_body': _get_body_for_logging(response.request.body),
            'status_sode': response.status_code,
            'response_body': _get_body_for_logging(response.content),
            'duration': _get_duration_for_logging(duration)}
        log_method(self.LOG_RESPONSE_TEMPLATE, message_params)
        
        
        
    def _make_request(self, method, url, **kwargs) -> requests.Response:
        kwargs.setdefault('timeout', self.timeout)
        session = self.session
        timeout = kwargs.pop('timeout', self.timeout)
        
        headers = self.default_headers.copy()
        headers.update(kwargs.pop('headers',{}))
        
        request = requests.Request(method, url, headers=headers, **kwargs)
        prepared_request = request.prepare()
        self._log_request(method, url, prepared_request.body)
        start_time = time.time()
        try:
            response = session.send(prepared_request, timeout=timeout)
            duration = time.time() - start_time
            if response.status_code>=400:
                log_method = logging.error
            else:
                log_method = logging.debug
                
            
            self._log_response(
                response, duration=duration, log_method=log_method)
            return response
        except requests.exceptions.RequestException as e:
            duration = time.time() - start_time
            if e.response:
                self._log_response(
                    e.response, duration=duration, log_method=logging.error)
            else:
                self._log_request(
                     method, url, prepared_request.body,
                     log_method=logging.exception)
            raise
        finally:
            if not self.keep_alive:
                session.close()
    
    @property
    def session(self) ->requests.Session:
        if self.keep_alive:
            if not self._session:
                self._session=requests.Session()
            return self._session
        else:
            return requests.Session()
        
    def get(self, url, params=None, **kwargs) -> requests.Response:
        if params:
            url_with_query_params=url+'?' +urlencode(params)
        else:
            url_with_query_params=url
            
        return self._make_request(
            self.GET_HTTP_METHOD, url_with_query_params, **kwargs)
        
        
    def post(self,url, **kwargs) -> requests.Response:
        return self._make_request(self.POST_HTTP_METHOD, url, **kwargs)

# %%
class GosUslugiAPIClient:
    REGION_CODES_AND_NAMES = REGION_CODES_AND_NAMES
    
    BASE_URL = 'https://dom.gosuslugi.ru/'
    LICENSE_UID_URL = (
        f'{BASE_URL}licenses/api/rest/services/public/'
        'licenses/region-license-xls/{}')
    HOUSE_CODE_URL = (
    f'{BASE_URL}nsi/api/rest/services/nsi/fias/v4/houses?'
        'houseCodes={}&includeDuplicates=false&actual={}')
    
    ORGANIZATIONS_URL = (
        f'{BASE_URL}ppa/api/rest/services/ppa/'
        'organizations/chooser/search;page=1;itemsPerPage=11')
    
    ORGANIZATION_URL = (
        f'{BASE_URL}ppa/api/rest/services/ppa/public/organizations'
        '/orgByGuid?organizationGuid={}')
    
    ORGANIZATION_PAYLOAD_PART_1 = (
        '{"sortCriteriaList":[{"sortedBy":"organizationType",'
        '"ascending":false},'
        '{"sortedBy":"shortName","ascending":true},{"sortedBy":"fullName",'
        '"ascending":true},{"sortedBy":"parentKpp","ascending":true},'
        '{"sortedBy":"kpp","ascending":true}],"organizationStatuses":'
        '{"coll":["REGISTERED"], "operand":"OR"}, "organizationTypes":'
        '{"coll":["B", "L", "A"], "operand": "OR"}, "subordinationOrgTypeList":'
        '{"coll":["HEAD", "BRANCH"], "operand":"OR"}, "commonSearchString":"')
    ORGANIZATION_PAYLOAD_PART_2 = (
        '",","roleConstraints":{"coll":[{"roleCode":"1",'
        '"roleStatuses":["APPROVED"]},{"roleCode":"19","roleStatuses":'
        '["APPROVED"]},{"roleCode":"20", "roleStatuses":["APPROVED"]},'
        '{"roleCode":"22", "roleStatuses":["APPROVED"]},'
        '{"roleCode":"21", "roleStatuses":["APPROVED"]}],"operand":"OR"}}')
    
    def __init__(self, timeout=5, keep_alive=False):
        self._region_codes = set(self.REGION_CODES_AND_NAMES)
        self._http_client = HTTPClient(timeout=timeout, keep_alive=keep_alive)
        
    def _get_response_body(self, response: requests.Response):
        status_code = response.status_code
        if status_code>=400:
            response.raise_for_status()
        elif not response.content:
            return ''
        else:
            return response.json()
        
    def get_organizations(self, inn):
        payload = self.ORGANIZATION_PAYLOAD_PART_1 + str(inn)
        payload += self.ORGANIZATION_PAYLOAD_PART_2
        
        url = self.ORGANIZATIONS_URL
        headers = {'Content-Type':'application/json'}
        response = self._http_client.post(url, data=payload, headers=headers)
        return self._get_response_body(response)
    
    def get_organization(self,guid):
        url = self.ORGANIZATION_URL.format(guid)
        return self._get_response_body(self._http_client.get(url))
    
    def get_actual_houses(self, house_code):
        url = self.HOUSE_CODE_URL.format(house_code, 'true')
        return self._get_response_body(self._http_client.get(url))
    
    def get_home_managements(self, org_guid, start_page=1, per_page=1):
        url=self.HOME_MANAGEMENTS_URL.format(
            page_number=start_page, elems_per_page=per_page)
        payload = json.dumps({'organizationGuid': org_guid, 'calcCount': True})
        headers = {'Content-Type': 'application/json'}
        response = requests.post(url, data=payload, headers=headers)
        json_body = self._get_response_body(response)
        yield json_body
        objects_number = json_body['total'] or 0
        for page_num in range(2, objects_number +1):
            url=self.HOME_MANAGEMENTS_URL.format(
                page_number=page_num, elems_per_page=per_page)
            response = requests.post(url, data=payload, headers=headers)
            yield self._get_response_body(response)

# %%
GO1=GosUslugiAPIClient()
#работает: guid взят с dom.gosuslugi.ru/#!/licensee-houses-info/
#GO1.get_organization('c3f46dba-f446-4d07-9122-bcc566434c93')

# %%
GO1=GosUslugiAPIClient()
#работает:
#GO1.get_actual_houses(house_code='5a541513-b462-449f-98f4-7dd660b49c9e')

# %%
GO1=GosUslugiAPIClient()
#работает:
#GO1.get_actual_houses(house_code='e4c272a8-63c3-45df-aa7f-76fdd1b622f9')

# %%
GO1=GosUslugiAPIClient()
#GO1.get_organizations('3435120482')

# %%
GO1=GosUslugiAPIClient()
GO1.get_home_managements('6d2367eb-92dc-493e-b38e-902b9ce32269')
# Out:
# <generator object GosUslugiAPIClient.get_home_managements at 0x7f956a743900>

# %% [markdown]
# We check all licence-holding functions by management companies:

# %%
LIZ_UID='050000924'

# %%
license_uid_url='https://dom.gosuslugi.ru/licenses/api/rest/services/public/licenses/region-license-xls/{}'.format(LIZ_UID)

# %%
Lic_results=requests.get(license_uid_url).json()

# %% [markdown]
# We also parse directly:

# %%
url='https://dom.gosuslugi.ru/#!/house-view?guid=a5893115-8e9d-4b4c-9fd6-9aa07fd59053&typeCode=1'

# %%
response = requests.get(url)
#print(response.text)

# %%
from bs4 import BeautifulSoup
r=requests.get(url)
with open('test.html','w') as output_file:output_file.write(r.text)

# %% [markdown]
# .. And indirectly via gosuslugi API (as suggested by Greg Eremeev - API developer):

# %%
from gosuslugi_api.clients import GosUslugiAPIClient

# %%
client=GosUslugiAPIClient()

# %%
#client.get_organizations('7706724054')

# %%
#client.get_organization('dfef9591-f591-47ac-9d65-794a2f8114c5')

# %%
client.get_organization('4105ee91-9191-4840-b788-f3d4db7c5f1b')
# Out:
# {'guid': '4105ee91-9191-4840-b788-f3d4db7c5f1b',
#  'createDate': None,
#  'lastEventDate': '2021-03-31 08:51:13',
#  'orgOid': '1063040229',
#  'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УПРАВЛЯЮЩАЯ КОМПАНИЯ ЮГСТРОЙИНВЕСТ"',
#  'shortName': 'ООО "УК ЮГСТРОЙИНВЕСТ"',
#  'ogrn': '1173443023830',
#  'ogrnip': None,
#  'inn': '3435132150',
#  'kpp': '343501001',
#  'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#   'code': '12300',
#   'rootEntityGuid': None,
#   'actual': True,
#   'lastUpdateDate': '2015-06-12 19:41:30',
#   'createDate': '2015-06-12 19:41:30',
#   'name': 'Общества с ограниченной ответственностью',
#   'parent': {'guid': '659a5227-0977-493a-a1a0-5695a088bf2c',
#    'code': '12000',
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': '2015-02-06 11:26:36',
#    'createDate': '2015-02-06 11:26:36',
#    'name': 'Хозяйственные общества',
#    'parent': {'guid': '50f87739-cd50-42bd-b059-c262040919a6',
#     'code': '10000',
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': '2015-02-06 11:26:36',
#     'createDate': '2015-02-06 11:26:36',
#     'name': 'ОРГАНИЗАЦИОННО-ПРАВОВЫЕ ФОРМЫ ЮРИДИЧЕСКИХ ЛИЦ, ЯВЛЯЮЩИХСЯ КОММЕРЧЕСКИМИ КОРПОРАТИВНЫМИ  ОРГАНИЗАЦИЯМИ',
#     'parent': None,
#     'status': None,
#     'level': 1,
#     'hasChildren': True,
#     'utvDate': None,
#     'vvedDate': None},
#    'status': None,
#    'level': 2,
#    'hasChildren': True,
#    'utvDate': None,
#    'vvedDate': None},
#   'status': None,
#   'level': 3,
#   'hasChildren': False,
#   'utvDate': None,
#   'vvedDate': None},
#  'orgAddress': '404118, ОБЛ. ВОЛГОГРАДСКАЯ, Г. Волжский, УЛ. МИРА, д. Д. 142А, кв. ПОМЕЩ. 3Н',
#  'postalAddress': {'region': {'guid': 'af757d44-3438-4040-9b68-d95099318998',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'aoLevel': 1,
#    'postalCode': None,
#    'formalName': 'Волгоградская',
#    'offName': 'Волгоградская',
#    'shortName': 'обл',
#    'parentGuid': None,
#    'oktmo': None,
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '000',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0000',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': None,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'area': None,
#   'city': {'guid': '00494b17-c617-4d8f-80e3-3aa8db508abc',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'aoLevel': 4,
#    'postalCode': None,
#    'formalName': 'Волжский',
#    'offName': 'Волжский',
#    'shortName': 'г',
#    'parentGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': None,
#     'rootEntityGuid': None,
#     'actual': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'name': None,
#     'controlNumber': None,
#     'additionalData': None,
#     'description': None,
#     'parent': None,
#     'status': None,
#     'level': None,
#     'hasChildren': None,
#     'hasActualChildren': None,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': None,
#     'vvedDate': None},
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '002',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0000',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'settlement': None,
#   'planningStructureElement': None,
#   'street': {'guid': 'b65b81d2-81fa-4163-80d0-b46bf1f4ddd1',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'd7ee03b0-0fd8-4e68-a5d7-84f86b2d0a5b',
#    'aoLevel': 7,
#    'postalCode': None,
#    'formalName': '87-й Гвардейской',
#    'offName': '87-й Гвардейской',
#    'shortName': 'ул',
#    'parentGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': None,
#     'rootEntityGuid': None,
#     'actual': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'name': None,
#     'controlNumber': None,
#     'additionalData': None,
#     'description': None,
#     'parent': None,
#     'status': None,
#     'level': None,
#     'hasChildren': None,
#     'hasActualChildren': None,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': None,
#     'vvedDate': None},
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '002',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0003',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'house': {'guid': '2b82ec60-27cb-407e-add0-aa74f1262942',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': '2021-04-24 16:50:48',
#    'createDate': '2021-04-23 16:50:48',
#    'houseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435',
#    'aoGuid': 'd7ee03b0-0fd8-4e68-a5d7-84f86b2d0a5b',
#    'postalCode': '404133',
#    'houseNumber': '25',
#    'buildingNumber': None,
#    'structNumber': None,
#    'additionalName': None,
#    'houseCondition': {'guid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#     'code': '2',
#     'rootEntityGuid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#     'actual': True,
#     'lastUpdateDate': '2015-02-06 11:19:01',
#     'createDate': '2015-02-06 11:19:01',
#     'houseCondition': 'Исправный'},
#    'propertyStateGuid': '4979fb1a-8373-4f99-b87b-0c4ee832da15',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': '18710000001',
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': '2021-02-03 16:41:58',
#     'createDate': '2015-02-06 11:26:36',
#     'name': 'г Волжский',
#     'controlNumber': 2,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '42fbb967-2aab-4b95-bf15-fff7476db320',
#      'code': '18710000000',
#      'rootEntityGuid': None,
#      'actual': True,
#      'lastUpdateDate': '2021-02-03 16:41:58',
#      'createDate': '2015-02-06 11:26:36',
#      'name': 'Населенные пункты, входящие в состав городского округа город Волжский',
#      'controlNumber': 9,
#      'additionalData': None,
#      'description': None,
#      'parent': {'guid': 'e3d86a1f-5f02-40c6-b835-08ce10b3aa8f',
#       'code': '18710000',
#       'rootEntityGuid': None,
#       'actual': True,
#       'lastUpdateDate': '2021-02-03 16:41:58',
#       'createDate': '2015-02-06 11:26:36',
#       'name': 'город Волжский',
#       'controlNumber': 9,
#       'additionalData': 'г Волжский',
#       'description': None,
#       'parent': {'guid': 'd295cbb2-bc89-4a93-88c1-f2185d548dfa',
#        'code': '18700000',
#        'rootEntityGuid': None,
#        'actual': True,
#        'lastUpdateDate': '2021-02-03 16:41:58',
#        'createDate': '2015-02-06 11:26:36',
#        'name': 'Городские округа Волгоградской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': {'guid': '46e1dd05-b2b0-45e1-b299-1d36a2307723',
#         'code': '18000000',
#         'rootEntityGuid': None,
#         'actual': True,
#         'lastUpdateDate': '2021-02-03 16:41:58',
#         'createDate': '2015-02-06 11:26:36',
#         'name': 'Муниципальные образования Волгоградской области',
#         'controlNumber': 6,
#         'additionalData': None,
#         'description': None,
#         'parent': None,
#         'status': None,
#         'level': 1,
#         'hasChildren': True,
#         'hasActualChildren': True,
#         'loadAttribute': None,
#         'oldMoscow': None,
#         'utvDate': '2013-06-14 00:00:00',
#         'vvedDate': '2014-01-01 00:00:00'},
#        'status': None,
#        'level': 2,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None,
#        'utvDate': '2013-06-14 00:00:00',
#        'vvedDate': '2014-01-01 00:00:00'},
#       'status': None,
#       'level': 3,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None,
#       'utvDate': '2013-06-14 00:00:00',
#       'vvedDate': '2014-01-01 00:00:00'},
#      'status': None,
#      'level': 6,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None,
#      'utvDate': '2013-06-14 00:00:00',
#      'vvedDate': '2014-01-01 00:00:00'},
#     'status': None,
#     'level': 7,
#     'hasChildren': False,
#     'hasActualChildren': False,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': '2013-06-14 00:00:00',
#     'vvedDate': '2014-01-01 00:00:00'},
#    'formattedAddress': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'estStatus': 'DOM',
#    'strStatus': 'NE_OPREDELENO',
#    'fiasHouseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435',
#    'aggregated': False,
#    'childAddresses': [],
#    'parentAggregatedGuid': None,
#    'houseTextAddress': '25',
#    'doubles': None,
#    'actualHouseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435'},
#   'additionalInfo': None,
#   'houseNumber': '25',
#   'buildingNumber': None,
#   'structNumber': None,
#   'formattedAddress': 'Волгоградская обл, г. Волжский, ул. 87-й Гвардейской, д. 25'},
#  'factualAddress': {'region': {'guid': 'af757d44-3438-4040-9b68-d95099318998',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'aoLevel': 1,
#    'postalCode': None,
#    'formalName': 'Волгоградская',
#    'offName': 'Волгоградская',
#    'shortName': 'обл',
#    'parentGuid': None,
#    'oktmo': None,
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '000',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0000',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': None,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'area': None,
#   'city': {'guid': '00494b17-c617-4d8f-80e3-3aa8db508abc',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'aoLevel': 4,
#    'postalCode': None,
#    'formalName': 'Волжский',
#    'offName': 'Волжский',
#    'shortName': 'г',
#    'parentGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': None,
#     'rootEntityGuid': None,
#     'actual': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'name': None,
#     'controlNumber': None,
#     'additionalData': None,
#     'description': None,
#     'parent': None,
#     'status': None,
#     'level': None,
#     'hasChildren': None,
#     'hasActualChildren': None,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': None,
#     'vvedDate': None},
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '002',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0000',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'settlement': None,
#   'planningStructureElement': None,
#   'street': {'guid': 'b65b81d2-81fa-4163-80d0-b46bf1f4ddd1',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'd7ee03b0-0fd8-4e68-a5d7-84f86b2d0a5b',
#    'aoLevel': 7,
#    'postalCode': None,
#    'formalName': '87-й Гвардейской',
#    'offName': '87-й Гвардейской',
#    'shortName': 'ул',
#    'parentGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': None,
#     'rootEntityGuid': None,
#     'actual': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'name': None,
#     'controlNumber': None,
#     'additionalData': None,
#     'description': None,
#     'parent': None,
#     'status': None,
#     'level': None,
#     'hasChildren': None,
#     'hasActualChildren': None,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': None,
#     'vvedDate': None},
#    'regionCode': '34',
#    'autoCode': '0',
#    'areaCode': '000',
#    'cityCode': '002',
#    'ctarCode': '000',
#    'placeCode': '000',
#    'planCode': None,
#    'streetCode': '0003',
#    'extrCode': '0000',
#    'sextCode': '000',
#    'updateDate': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': None},
#   'house': {'guid': '2b82ec60-27cb-407e-add0-aa74f1262942',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': '2021-04-24 16:50:48',
#    'createDate': '2021-04-23 16:50:48',
#    'houseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435',
#    'aoGuid': 'd7ee03b0-0fd8-4e68-a5d7-84f86b2d0a5b',
#    'postalCode': '404133',
#    'houseNumber': '25',
#    'buildingNumber': None,
#    'structNumber': None,
#    'additionalName': None,
#    'houseCondition': {'guid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#     'code': '2',
#     'rootEntityGuid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#     'actual': True,
#     'lastUpdateDate': '2015-02-06 11:19:01',
#     'createDate': '2015-02-06 11:19:01',
#     'houseCondition': 'Исправный'},
#    'propertyStateGuid': '4979fb1a-8373-4f99-b87b-0c4ee832da15',
#    'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#     'code': '18710000001',
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': '2021-02-03 16:41:58',
#     'createDate': '2015-02-06 11:26:36',
#     'name': 'г Волжский',
#     'controlNumber': 2,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '42fbb967-2aab-4b95-bf15-fff7476db320',
#      'code': '18710000000',
#      'rootEntityGuid': None,
#      'actual': True,
#      'lastUpdateDate': '2021-02-03 16:41:58',
#      'createDate': '2015-02-06 11:26:36',
#      'name': 'Населенные пункты, входящие в состав городского округа город Волжский',
#      'controlNumber': 9,
#      'additionalData': None,
#      'description': None,
#      'parent': {'guid': 'e3d86a1f-5f02-40c6-b835-08ce10b3aa8f',
#       'code': '18710000',
#       'rootEntityGuid': None,
#       'actual': True,
#       'lastUpdateDate': '2021-02-03 16:41:58',
#       'createDate': '2015-02-06 11:26:36',
#       'name': 'город Волжский',
#       'controlNumber': 9,
#       'additionalData': 'г Волжский',
#       'description': None,
#       'parent': {'guid': 'd295cbb2-bc89-4a93-88c1-f2185d548dfa',
#        'code': '18700000',
#        'rootEntityGuid': None,
#        'actual': True,
#        'lastUpdateDate': '2021-02-03 16:41:58',
#        'createDate': '2015-02-06 11:26:36',
#        'name': 'Городские округа Волгоградской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': {'guid': '46e1dd05-b2b0-45e1-b299-1d36a2307723',
#         'code': '18000000',
#         'rootEntityGuid': None,
#         'actual': True,
#         'lastUpdateDate': '2021-02-03 16:41:58',
#         'createDate': '2015-02-06 11:26:36',
#         'name': 'Муниципальные образования Волгоградской области',
#         'controlNumber': 6,
#         'additionalData': None,
#         'description': None,
#         'parent': None,
#         'status': None,
#         'level': 1,
#         'hasChildren': True,
#         'hasActualChildren': True,
#         'loadAttribute': None,
#         'oldMoscow': None,
#         'utvDate': '2013-06-14 00:00:00',
#         'vvedDate': '2014-01-01 00:00:00'},
#        'status': None,
#        'level': 2,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None,
#        'utvDate': '2013-06-14 00:00:00',
#        'vvedDate': '2014-01-01 00:00:00'},
#       'status': None,
#       'level': 3,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None,
#       'utvDate': '2013-06-14 00:00:00',
#       'vvedDate': '2014-01-01 00:00:00'},
#      'status': None,
#      'level': 6,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None,
#      'utvDate': '2013-06-14 00:00:00',
#      'vvedDate': '2014-01-01 00:00:00'},
#     'status': None,
#     'level': 7,
#     'hasChildren': False,
#     'hasActualChildren': False,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': '2013-06-14 00:00:00',
#     'vvedDate': '2014-01-01 00:00:00'},
#    'formattedAddress': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'estStatus': 'DOM',
#    'strStatus': 'NE_OPREDELENO',
#    'fiasHouseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435',
#    'aggregated': False,
#    'childAddresses': [],
#    'parentAggregatedGuid': None,
#    'houseTextAddress': '25',
#    'doubles': None,
#    'actualHouseGuid': 'c76ffdb4-5a6b-47b5-96a1-1afd4c518435'},
#   'additionalInfo': None,
#   'houseNumber': '25',
#   'buildingNumber': None,
#   'structNumber': None,
#   'formattedAddress': 'Волгоградская обл, г. Волжский, ул. 87-й Гвардейской, д. 25'},
#  'authorityFactualAddress': None,
#  'phone': '+7(961)6695428',
#  'faxes': ['+7(8443)777019'],
#  'orgEmail': 'ukusi34@mail.ru',
#  'url': 'uk-usi34.ru',
#  'stateRegistrationDate': '2017-10-20 00:00:00',
#  'chiefLastName': 'Скобора',
#  'chiefFirstName': 'Дмитрий',
#  'chiefMiddleName': 'Александрович',
#  'organizationType': 'L',
#  'okfs': None,
#  'timeZone': {'guid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#   'code': '4',
#   'rootEntityGuid': None,
#   'actual': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'utcCode': None,
#   'mskCode': None,
#   'olsonTZList': [{'guid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#     'code': '4',
#     'rootEntityGuid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#     'actual': True,
#     'lastUpdateDate': '2015-02-06 11:19:00',
#     'createDate': '2015-02-06 11:19:00',
#     'olsonCode': 'Europe/Volgograd',
#     'russianName': 'Волгоград',
#     'utcCode': 'UTC+4'}],
#   'name': None},
#  'okogu': None,
#  'organizationRoles': [{'guid': 'fe816ad5-a04b-4b67-802d-82107cfc354d',
#    'createDate': '2018-01-24 17:59:45',
#    'lastEventDate': '2018-01-24 17:59:45',
#    'role': {'guid': '52f5e0a4-7f4c-4fb1-9423-160e9178ddda',
#     'code': '1',
#     'rootEntityGuid': '52f5e0a4-7f4c-4fb1-9423-160e9178ddda',
#     'actual': True,
#     'lastUpdateDate': '2015-02-06 11:19:01',
#     'createDate': '2015-02-06 11:19:01',
#     'organizationRoleName': 'Управляющая организация',
#     'shortName': 'УО',
#     'citizenRole': False},
#    'status': 'APPROVED',
#    'reasons': [],
#    'region': {'guid': 'af757d44-3438-4040-9b68-d95099318998',
#     'code': None,
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Волгоградская',
#     'offName': 'Волгоградская',
#     'shortName': 'область',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '34',
#     'autoCode': '0',
#     'areaCode': '000',
#     'cityCode': '000',
#     'ctarCode': '000',
#     'placeCode': '000',
#     'planCode': None,
#     'streetCode': '0000',
#     'extrCode': '0000',
#     'sextCode': '000',
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False}}],
#  'municipalResource': None,
#  'registryOrganizationRootEntityGuid': '311d2e0d-ce17-4963-b46a-9bc637d3e2a2',
#  'bankCode': None,
#  'additionalInfo': None,
#  'branchOrganizationInfos': [],
#  'parentOrg': None,
#  'branch': False}

# %%
client.get_home_management('a5893115-8e9d-4b4c-9fd6-9aa07fd59053')
#аргумент - guid из url адреса карточки дома = home_management_guid
# Out:
# {'guid': 'a5893115-8e9d-4b4c-9fd6-9aa07fd59053',
#  'rootGuid': None,
#  'versionNumber': None,
#  'lastUpdateUnixTime': None,
#  'lastUpdateDate': None,
#  'createDate': None,
#  'readOnly': None,
#  'active': None,
#  'asyncProcessing': None,
#  'asyncProcessType': None,
#  'status': 'APPROVED',
#  'cancellationReasonCode': None,
#  'cancellationComment': None,
#  'cancellationDate': None,
#  'address': {'region': {'guid': 'af757d44-3438-4040-9b68-d95099318998',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'aoLevel': 1,
#    'postalCode': None,
#    'formalName': 'Волгоградская',
#    'offName': 'Волгоградская',
#    'shortName': 'обл',
#    'parentGuid': None,
#    'oktmo': None,
#    'regionCode': '34',
#    'autoCode': None,
#    'areaCode': None,
#    'cityCode': None,
#    'ctarCode': None,
#    'placeCode': None,
#    'planCode': None,
#    'streetCode': None,
#    'extrCode': None,
#    'sextCode': None,
#    'updateDate': None,
#    'isAddedManually': None,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': False},
#   'area': None,
#   'city': {'guid': '00494b17-c617-4d8f-80e3-3aa8db508abc',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'aoLevel': 4,
#    'postalCode': None,
#    'formalName': 'Волжский',
#    'offName': 'Волжский',
#    'shortName': 'г',
#    'parentGuid': 'da051ec8-da2e-4a66-b542-473b8d221ab4',
#    'oktmo': None,
#    'regionCode': '34',
#    'autoCode': None,
#    'areaCode': None,
#    'cityCode': None,
#    'ctarCode': None,
#    'placeCode': None,
#    'planCode': None,
#    'streetCode': None,
#    'extrCode': None,
#    'sextCode': None,
#    'updateDate': None,
#    'isAddedManually': None,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': False},
#   'ctar': None,
#   'additionalTerritory': None,
#   'additionalTerStreet': None,
#   'settlement': None,
#   'planningStructureElement': None,
#   'street': {'guid': '8f9e0c2f-e92a-4343-b1f6-f0b50fbb2849',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'aoGuid': '1b3c6f13-85c7-4836-867c-d2b563e64db5',
#    'aoLevel': 7,
#    'postalCode': None,
#    'formalName': 'им генерала Карбышева',
#    'offName': 'им генерала Карбышева',
#    'shortName': 'ул',
#    'parentGuid': 'bc5ed788-84c8-493e-9598-7a15a9f1e4c1',
#    'oktmo': None,
#    'regionCode': '34',
#    'autoCode': None,
#    'areaCode': None,
#    'cityCode': None,
#    'ctarCode': None,
#    'placeCode': None,
#    'planCode': None,
#    'streetCode': None,
#    'extrCode': None,
#    'sextCode': None,
#    'updateDate': None,
#    'isAddedManually': None,
#    'onApproval': None,
#    'fiasAddrobjGuid': None,
#    'subjectCity': False},
#   'house': {'guid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9',
#    'code': None,
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': None,
#    'createDate': None,
#    'houseGuid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9',
#    'aoGuid': '1b3c6f13-85c7-4836-867c-d2b563e64db5',
#    'postalCode': '404133',
#    'houseNumber': '170',
#    'buildingNumber': None,
#    'structNumber': None,
#    'additionalName': None,
#    'houseCondition': None,
#    'propertyStateGuid': None,
#    'oktmo': None,
#    'formattedAddress': None,
#    'isAddedManually': False,
#    'onApproval': None,
#    'estStatus': 'DOM',
#    'strStatus': 'NE_OPREDELENO',
#    'fiasHouseGuid': None,
#    'aggregated': False,
#    'childAddresses': None,
#    'parentAggregatedGuid': None,
#    'houseTextAddress': '170',
#    'doubles': None,
#    'actualHouseGuid': None},
#   'formattedAddress': '404133, обл Волгоградская, г Волжский, ул им генерала Карбышева, д. 170',
#   'deprecated': False},
#  'rosreestrRootGuid': None,
#  'oktmo': {'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#   'code': '18710000001',
#   'rootEntityGuid': None,
#   'actual': True,
#   'lastUpdateDate': '03.02.2021',
#   'createDate': '06.02.2015',
#   'name': 'г Волжский',
#   'controlNumber': 2,
#   'additionalData': None,
#   'description': None,
#   'parent': {'guid': '42fbb967-2aab-4b95-bf15-fff7476db320',
#    'code': '18710000000',
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': '03.02.2021',
#    'createDate': '06.02.2015',
#    'name': 'Населенные пункты, входящие в состав городского округа город Волжский',
#    'controlNumber': 9,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'e3d86a1f-5f02-40c6-b835-08ce10b3aa8f',
#     'code': '18710000',
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': '03.02.2021',
#     'createDate': '06.02.2015',
#     'name': 'город Волжский',
#     'controlNumber': 9,
#     'additionalData': 'г Волжский',
#     'description': None,
#     'parent': {'guid': 'd295cbb2-bc89-4a93-88c1-f2185d548dfa',
#      'code': '18700000',
#      'rootEntityGuid': None,
#      'actual': True,
#      'lastUpdateDate': '03.02.2021',
#      'createDate': '06.02.2015',
#      'name': 'Городские округа Волгоградской области',
#      'controlNumber': 5,
#      'additionalData': None,
#      'description': None,
#      'parent': {'guid': '46e1dd05-b2b0-45e1-b299-1d36a2307723',
#       'code': '18000000',
#       'rootEntityGuid': None,
#       'actual': True,
#       'lastUpdateDate': '03.02.2021',
#       'createDate': '06.02.2015',
#       'name': 'Муниципальные образования Волгоградской области',
#       'controlNumber': 6,
#       'additionalData': None,
#       'description': None,
#       'parent': None,
#       'status': None,
#       'level': 1,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014'},
#      'status': None,
#      'level': 2,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014'},
#     'status': None,
#     'level': 3,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014'},
#    'status': None,
#    'level': 6,
#    'hasChildren': True,
#    'hasActualChildren': True,
#    'loadAttribute': None,
#    'oldMoscow': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014'},
#   'status': None,
#   'level': 7,
#   'hasChildren': False,
#   'hasActualChildren': False,
#   'loadAttribute': None,
#   'oldMoscow': None,
#   'utvDate': '14.06.2013',
#   'vvedDate': '01.01.2014'},
#  'oldOktmo': None,
#  'oktmoReadOnly': None,
#  'parentOktmos': [],
#  'oktmoFromFias': None,
#  'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#   'code': '1',
#   'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#   'actual': True,
#   'lastUpdateDate': '06.02.2015',
#   'createDate': '06.02.2015',
#   'houseTypeName': 'Многоквартирный'},
#  'houseUid': 'KAA02462',
#  'cadastreNumber': '34:35:030214:6519',
#  'oldCadastreNumber': None,
#  'cadastreNumberIsAbsent': None,
#  'floorCount': None,
#  'floorCountReadOnly': None,
#  'totalSquare': '3441.6',
#  'totalSquareReadOnly': None,
#  'residentialSquare': '2416',
#  'landSurveyTotalSquare': None,
#  'landSurveyTotalSquareReadOnly': None,
#  'cadastreRemovalDate': None,
#  'managementOrganization': {'guid': '4105ee91-9191-4840-b788-f3d4db7c5f1b',
#   'createDate': '24.01.2018',
#   'lastEventDate': '31.03.2021',
#   'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УПРАВЛЯЮЩАЯ КОМПАНИЯ ЮГСТРОЙИНВЕСТ"',
#   'shortName': 'ООО "УК ЮГСТРОЙИНВЕСТ"',
#   'orgAddress': '404118, ОБЛ. ВОЛГОГРАДСКАЯ, Г. Волжский, УЛ. МИРА, д. Д. 142А, кв. ПОМЕЩ. 3Н',
#   'phone': '+7(961)6695428',
#   'url': 'uk-usi34.ru',
#   'organizationType': 'L',
#   'olsonTZ': {'guid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#    'createDate': None,
#    'lastEventDate': None,
#    'code': '4'},
#   'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#    'createDate': None,
#    'lastEventDate': None,
#    'code': '12300'},
#   'registryOrganizationRootEntityGuid': '311d2e0d-ce17-4963-b46a-9bc637d3e2a2',
#   'parentGuid': None,
#   'ogrn': '1173443023830'},
#  'managementOrganizationRole': True,
#  'houseCondition': {'guid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#   'code': '2',
#   'rootEntityGuid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#   'actual': True,
#   'lastUpdateDate': '06.02.2015',
#   'createDate': '06.02.2015',
#   'houseCondition': 'Исправный'},
#  'lifeCycleStage': None,
#  'houseManagementType': {'guid': 'bfb270d2-43f1-4859-bd3c-89618e20acad',
#   'code': '5',
#   'rootEntityGuid': 'bfb270d2-43f1-4859-bd3c-89618e20acad',
#   'actual': True,
#   'lastUpdateDate': '06.02.2015',
#   'createDate': '06.02.2015',
#   'houseManagementTypeName': 'УО'},
#  'deterioration': None,
#  'buildingYear': '2017',
#  'operationYear': 2017,
#  'operationYearReadOnly': None,
#  'planSeries': '1369-1,3-АР.ГЧ',
#  'documentGuid': None,
#  'documentType': None,
#  'managementContractDate': '01.05.2019',
#  'endContractDate': None,
#  'attachments': None,
#  'accountCount': None,
#  'intWallMaterialList': 'Гипсолитовые',
#  'houseEnergyEfficiency': None,
#  'energyInspectionDate': None,
#  'municipalityOrganizationList': [{'guid': '0fc3cccc-457c-44fc-8488-5117e3f82833',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'КОМИТЕТ ПО ОБЕСПЕЧЕНИЮ ЖИЗНЕДЕЯТЕЛЬНОСТИ ГОРОДА АДМИНИСТРАЦИИ ГОРОДСКОГО ОКРУГА - ГОРОД ВОЛЖСКИЙ ВОЛГОГРАДСКОЙ ОБЛАСТИ',
#    'shortName': 'КЖД',
#    'orgAddress': '404130, Волгоградская обл, г Волжский, ул 19 Партсъезда, д. 30',
#    'phone': '+7(8443)413162',
#    'url': 'http://newwebadm.admvol/Departments/podrobno.asp?id=1',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '0f77cde5-2a60-42c2-a7e3-be8df5dacbe1',
#    'parentGuid': None,
#    'ogrn': '1043400050759'},
#   {'guid': '26d8854c-d895-4c1d-a0f5-cea4160a0e68',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'КОМИТЕТ БЛАГОУСТРОЙСТВА И ДОРОЖНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДСКОГО ОКРУГА - ГОРОД ВОЛЖСКИЙ ВОЛГОГРАДСКОЙ ОБЛАСТИ',
#    'shortName': 'КБИДХ',
#    'orgAddress': '404130, ОБЛАСТЬ ВОЛГОГРАДСКАЯ, ГОРОД ВОЛЖСКИЙ, УЛИЦА 19 ПАРТСЪЕЗДА, д. ДОМ 30',
#    'phone': '+7(8443)415977',
#    'url': None,
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': 'fd80a523-1bb2-4843-a602-38c90d7d1c48',
#    'parentGuid': None,
#    'ogrn': '1153435005789'},
#   {'guid': '2b63f506-f40f-4b9e-bdf5-da622af73e0f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'АДМИНИСТРАЦИЯ ГОРОДСКОГО ОКРУГА - ГОРОД ВОЛЖСКИЙ ВОЛГОГРАДСКОЙ ОБЛАСТИ',
#    'shortName': 'Администрация городского округа - город Волжский Волгоградской области',
#    'orgAddress': '404130, ОБЛ ВОЛГОГРАДСКАЯ, Г ВОЛЖСКИЙ, ПР-КТ ИМ ЛЕНИНА, д. 21',
#    'phone': '+7 (844) 342-13-51',
#    'url': 'admvol.ru',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '8bd62de1-98b3-4e1f-9bd6-66d386e03492',
#    'parentGuid': None,
#    'ogrn': '1023402008706'},
#   {'guid': '40bb4aa4-745a-4b14-bf21-5bea07ce4278',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ МУНИЦИПАЛЬНЫМ ИМУЩЕСТВОМ АДМИНИСТРАЦИИ ГОРОДСКОГО ОКРУГА - ГОРОД ВОЛЖСКИЙ ВОЛГОГРАДСКОЙ ОБЛАСТИ',
#    'shortName': 'УМИ Г. ВОЛЖСКОГО',
#    'orgAddress': '404130, ОБЛ ВОЛГОГРАДСКАЯ, Г ВОЛЖСКИЙ, ПР-КТ ИМ ЛЕНИНА, д. 21',
#    'phone': '+7 (844) 341-56-03',
#    'url': 'http://www.admvol.ru/Departments/podrobno.asp?id=9',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '98d7fcd1-abd1-47fb-afeb-91fc4ba7edb7',
#    'parentGuid': None,
#    'ogrn': '1023402012589'}],
#  'culturalHeritage': None,
#  'culturalHeritageReadOnly': None,
#  'landPlotCadastreNumber': None,
#  'prevStateRegNumber': None,
#  'olsonTZ': None,
#  'apartmentsExist': None,
#  'rosreestrVersionsHistoryExists': None,
#  'votingResultGuid': None,
#  'canUnlinkFromRosreestr': None,
#  'canAdd': None,
#  'hasMunicipalServices': None,
#  'isLicenseInfoExist': None,
#  'fmsInfo': None,
#  'canUpdateFms': None,
#  'canCancel': None,
#  'cancellationReason': None,
#  'hasIncorrectObjects': None,
#  'houseMappingInfo': None,
#  'demolitionDate': None,
#  'demolitionReason': None,
#  'demolitionAttachments': [],
#  'emergencyDocumentNumber': None,
#  'emergencyDocumentDate': None,
#  'houseTypeReadOnly': False,
#  'resourceProvisionOrganizationList': [{'guid': 'fb649d46-b971-49f1-b5bf-8e1c90eb42aa',
#    'createDate': '08.06.2015',
#    'lastEventDate': '06.04.2021',
#    'fullName': 'МУНИЦИПАЛЬНОЕ УНИТАРНОЕ ПРЕДПРИЯТИЕ "ВОДОПРОВОДНО-КАНАЛИЗАЦИОННОЕ ХОЗЯЙСТВО" ГОРОДСКОГО ОКРУГА - ГОРОД ВОЛЖСКИЙ ВОЛГОГРАДСКОЙ ОБЛАСТИ',
#    'shortName': 'МУП "Водоканал"',
#    'orgAddress': '404130, ОБЛАСТЬ ВОЛГОГРАДСКАЯ, ГОРОД ВОЛЖСКИЙ, УЛИЦА ПУШКИНА, д. 16А',
#    'phone': '+7 (8443) 45-45-50',
#    'url': 'http://www.vkanal.ru/',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '4'},
#    'okopf': {'guid': '36c898a0-46a2-4854-a1ed-493fd61d2fde',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '65243'},
#    'registryOrganizationRootEntityGuid': '844a32a6-0ebc-40f0-b59e-88b39c2fc8c2',
#    'parentGuid': None,
#    'ogrn': '1023402004240'},
#   {'guid': '4d6ba006-1af1-4510-af4f-64740938a93d',
#    'createDate': '03.09.2015',
#    'lastEventDate': '15.04.2019',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГАЗПРОМ МЕЖРЕГИОНГАЗ ВОЛГОГРАД"',
#    'shortName': 'ООО "Газпром межрегионгаз Волгоград"',
#    'orgAddress': '400001, ОБЛАСТЬ ВОЛГОГРАДСКАЯ, ГОРОД ВОЛГОГРАД, УЛИЦА КОВРОВСКАЯ, д. 13',
#    'phone': '(8442) 93-11-91',
#    'url': 'www.34regiongaz.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': 'fac01e32-9702-4fc0-ae4e-4ba8bcc5890e',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '2'},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300'},
#    'registryOrganizationRootEntityGuid': '21fb4a35-9923-4f86-a259-b61de763879f',
#    'parentGuid': None,
#    'ogrn': '1023403844441'},
#   {'guid': '0019eaec-8268-4447-975a-446ee469f3d2',
#    'createDate': '14.08.2015',
#    'lastEventDate': '28.12.2020',
#    'fullName': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "ВОЛГОГРАДЭНЕРГОСБЫТ"',
#    'shortName': 'ПАО "ВОЛГОГРАДЭНЕРГОСБЫТ"',
#    'orgAddress': '400001, ОБЛАСТЬ ВОЛГОГРАДСКАЯ, ГОРОД ВОЛГОГРАД, УЛИЦА КОЗЛОВСКАЯ, д. 14',
#    'phone': '+7(844)2262626',
#    'url': 'www.energosale34.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '62097368-08e7-48a3-9aeb-b1d81ad4e002',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '4'},
#    'okopf': {'guid': '3e3a091b-39b3-4dae-af76-8d463684065b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12247'},
#    'registryOrganizationRootEntityGuid': 'bd61fa71-3bfc-4611-94d8-7143af9868ec',
#    'parentGuid': None,
#    'ogrn': '1053444090028'}],
#  'reconstructionYear': None,
#  'minFloorCount': None,
#  'undergroundFloorCount': None,
#  'undergroundFloorCountReadOnly': None,
#  'overhaulFundContribution': None,
#  'overhaulFundForming': None,
#  'protocolGuid': None,
#  'rentAgreementList': None,
#  'estateObjectParams': None,
#  'canViewEGRP': None,
#  'residentialPremiseActualCount': None,
#  'nonResidentialPremiseActualCount': None,
#  'residentialPremiseConfirmedCount': None,
#  'nonResidentialPremiseConfirmedCount': None,
#  'buildingSquare': None,
#  'deteriorationDate': None,
#  'chiefFirstName': None,
#  'chiefLastName': None,
#  'chiefMiddleName': None,
#  'approved': True,
#  'canceledOrAsyncProcessed': False,
#  'houseCancelled': False}

# %%
client.get_actual_houses('e4c272a8-63c3-45df-aa7f-76fdd1b622f9')
#аргумент - идентификационный код адреса из карточки дома = house code
# Out:
# [{'guid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9',
#   'code': None,
#   'rootEntityGuid': None,
#   'actual': True,
#   'lastUpdateDate': '24.04.2021 16:39',
#   'createDate': '23.04.2021 16:39',
#   'houseGuid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9',
#   'aoGuid': '1b3c6f13-85c7-4836-867c-d2b563e64db5',
#   'postalCode': '404133',
#   'houseNumber': '170',
#   'buildingNumber': None,
#   'structNumber': None,
#   'additionalName': None,
#   'houseCondition': {'classType': 'ru.lanit.hcs.nsi.api.dto.HouseCondition',
#    'guid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#    'code': '2',
#    'rootEntityGuid': '2d3ae73e-6c72-4740-9122-9c632d1893a7',
#    'actual': True,
#    'lastUpdateDate': '06.02.2015 11:19',
#    'createDate': '06.02.2015 11:19',
#    'houseCondition': 'Исправный'},
#   'propertyStateGuid': '4979fb1a-8373-4f99-b87b-0c4ee832da15',
#   'oktmo': {'classType': 'ru.lanit.hcs.nsi.api.dto.Oktmo',
#    'guid': 'c9d955ce-7599-409d-9813-a9cbe3346d5b',
#    'code': '18710000001',
#    'rootEntityGuid': None,
#    'actual': True,
#    'lastUpdateDate': '03.02.2021 16:41',
#    'createDate': '06.02.2015 11:26',
#    'name': 'г Волжский',
#    'controlNumber': 2,
#    'additionalData': None,
#    'description': None,
#    'parent': {'classType': 'ru.lanit.hcs.nsi.api.dto.Oktmo',
#     'guid': '42fbb967-2aab-4b95-bf15-fff7476db320',
#     'code': '18710000000',
#     'rootEntityGuid': None,
#     'actual': True,
#     'lastUpdateDate': '03.02.2021 16:41',
#     'createDate': '06.02.2015 11:26',
#     'name': 'Населенные пункты, входящие в состав городского округа город Волжский',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'classType': 'ru.lanit.hcs.nsi.api.dto.Oktmo',
#      'guid': 'e3d86a1f-5f02-40c6-b835-08ce10b3aa8f',
#      'code': '18710000',
#      'rootEntityGuid': None,
#      'actual': True,
#      'lastUpdateDate': '03.02.2021 16:41',
#      'createDate': '06.02.2015 11:26',
#      'name': 'город Волжский',
#      'controlNumber': 9,
#      'additionalData': 'г Волжский',
#      'description': None,
#      'parent': {'classType': 'ru.lanit.hcs.nsi.api.dto.Oktmo',
#       'guid': 'd295cbb2-bc89-4a93-88c1-f2185d548dfa',
#       'code': '18700000',
#       'rootEntityGuid': None,
#       'actual': True,
#       'lastUpdateDate': '03.02.2021 16:41',
#       'createDate': '06.02.2015 11:26',
#       'name': 'Городские округа Волгоградской области',
#       'controlNumber': 5,
#       'additionalData': None,
#       'description': None,
#       'parent': {'classType': 'ru.lanit.hcs.nsi.api.dto.Oktmo',
#        'guid': '46e1dd05-b2b0-45e1-b299-1d36a2307723',
#        'code': '18000000',
#        'rootEntityGuid': None,
#        'actual': True,
#        'lastUpdateDate': '03.02.2021 16:41',
#        'createDate': '06.02.2015 11:26',
#        'name': 'Муниципальные образования Волгоградской области',
#        'controlNumber': 6,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None,
#        'utvDate': '14.06.2013 00:00',
#        'vvedDate': '01.01.2014 00:00'},
#       'status': None,
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None,
#       'utvDate': '14.06.2013 00:00',
#       'vvedDate': '01.01.2014 00:00'},
#      'status': None,
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None,
#      'utvDate': '14.06.2013 00:00',
#      'vvedDate': '01.01.2014 00:00'},
#     'status': None,
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None,
#     'utvDate': '14.06.2013 00:00',
#     'vvedDate': '01.01.2014 00:00'},
#    'status': None,
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None,
#    'utvDate': '14.06.2013 00:00',
#    'vvedDate': '01.01.2014 00:00'},
#   'formattedAddress': None,
#   'isAddedManually': False,
#   'onApproval': None,
#   'estStatus': 'DOM',
#   'strStatus': 'NE_OPREDELENO',
#   'fiasHouseGuid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9',
#   'aggregated': False,
#   'childAddresses': [],
#   'parentAggregatedGuid': None,
#   'houseTextAddress': '170',
#   'doubles': None,
#   'actualHouseGuid': 'e4c272a8-63c3-45df-aa7f-76fdd1b622f9'}]

# %% [markdown]
# After having all the data needed , it is required to upload them into Excel format ready-to-run the regression analysis.
